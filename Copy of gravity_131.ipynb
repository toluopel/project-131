# %%
import pandas as pd

# %%
df = pd.read_csv('final.csv')

# %%
df.head()
# Out:
#    Unnamed: 0         VMag       Star_name Bayer Designation     Distance  \
# 0           0  0.000−26.74             Sun               NaN  0.000015813
# 1           1   0.001−1.46          Sirius             α CMa       0008.6
# 2           2   0.003−0.74         Canopus             α Car         0310
# 3           3   0.004−0.27  Alpha Centauri             α Cen       0004.4
# 4           4   0.005−0.05        Arcturus             α Boo         0037
#
#   Spectral Class Mass Radius
# 0             G2    1      1
# 1             A1  2.1  1.71´
# 2             A9   15     71
# 3             G2  1.1    1.2
# 4             K2  1.1     26

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'VMag', 'Star_name', 'Bayer Designation', 'Distance',
#        'Spectral Class', 'Mass', 'Radius'],
#       dtype='object')

# %%
df.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
df.head()
# Out:
#           VMag       Star_name Bayer Designation     Distance Spectral Class  \
# 0  0.000−26.74             Sun               NaN  0.000015813             G2
# 1   0.001−1.46          Sirius             α CMa       0008.6             A1
# 2   0.003−0.74         Canopus             α Car         0310             A9
# 3   0.004−0.27  Alpha Centauri             α Cen       0004.4             G2
# 4   0.005−0.05        Arcturus             α Boo         0037             K2
#
#   Mass Radius
# 0    1      1
# 1  2.1  1.71´
# 2   15     71
# 3  1.1    1.2
# 4  1.1     26

# %%
df.dtypes
# Out:
# VMag                 object
# Star_name            object
# Bayer Designation    object
# Distance             object
# Spectral Class       object
# Mass                 object
# Radius               object
# dtype: object

# %%
df['Radius']=df['Radius'].apply(lambda x: x.replace('$', '').replace(',', '')).astype('float')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6336/2984955950.py in <module>
# ----> 1 df['Radius']=df['Radius'].apply(lambda x: x.replace('$', '').replace(',', '')).astype('float')
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1097                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1098                 # "Callable[[Any], Any]"
# -> 1099                 mapped = lib.map_infer(
#    1100                     values,
#    1101                     f,  # type: ignore[arg-type]
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ~\AppData\Local\Temp/ipykernel_6336/2984955950.py in <lambda>(x)
# ----> 1 df['Radius']=df['Radius'].apply(lambda x: x.replace('$', '').replace(',', '')).astype('float')
#
# AttributeError: 'float' object has no attribute 'replace'

# %%
radius = df['Radius'].to_list()
mass = df['Mass'].to_list()
gravity =[]

#converting solar mass and radius into km & kg
def convert_to_si(radius,mass):
    for i in range(0,len(radius)-1):
        radius[i] = radius[i]*6.957e+8
        mass[i] = mass[i]*1.989e+30
        
convert_to_si(radius,mass)

# %%
def gravity_calculation(radius,mass):
    G = 6.674e-11
    for index in range(0,len(mass)):
        g= (mass[index]*G)/((radius[index])**2)
        gravity.append(g)
        
gravity_calculation(radius,mass)

df["Gravity"] = gravity
df
# Out:
#                   Star_name    Distance       Mass     Radius       Gravity
# 0                       Sun    0.000016   1.000000   1.000000  2.742692e+02
# 1                    Sirius    8.600000   2.100000   1.710000  1.969718e+02
# 2                   Canopus  310.000000  15.000000  71.000000  8.161153e-01
# 3            Alpha Centauri    4.400000   1.100000   1.200000  2.095112e+02
# 4                  Arcturus   37.000000   1.100000  26.000000  4.462960e-01
# ..                      ...         ...        ...        ...           ...
# 248  2MASSI J2356547-155310   74.000000   0.076367   0.112012  1.669385e+03
# 249          WISE 0410+1502   20.000000   0.005728   0.120233  1.086673e+02
# 250         WISE 0458+6434A   35.900000   0.014319   0.431605  2.108201e+01
# 251         WISE 0458+6434B   35.900000   0.009546   0.390499  1.716928e+01
# 252          WISE 1405+5534   25.300000   0.028638   0.088376  2.447107e-10
#
# [253 rows x 5 columns]

# %%
#df['Distance']=df['Distance'].apply(lambda x: x.replace('$', '').replace(',', '')).astype('float')
df.to_csv("star_with_gravity.csv")

# %%
df.dtypes
# Out:
# Star_name     object
# Distance     float64
# Mass         float64
# Radius       float64
# Gravity      float64
# dtype: object
